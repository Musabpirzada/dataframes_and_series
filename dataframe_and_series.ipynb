# %%
import pandas as pd

# %%
people = {
    "first":["Corey", "musab", 'Ahmad'],
    "last" : ["Schexx", "pirzada", "khan"],
    "email" : ["corey@gmail.com", "musab@gmail.com", "ahmad@gmail.com"]
}

# %%
df = pd.DataFrame(people)
df
# Out:
#    first     last            email
# 0  Corey   Schexx  corey@gmail.com
# 1  musab  pirzada  musab@gmail.com
# 2  Ahmad     khan  ahmad@gmail.com

# %%
df['email']
# Out:
# 0    corey@gmail.com
# 1    musab@gmail.com
# 2    ahmad@gmail.com
# Name: email, dtype: object

# %%
type(df['email'])
# Out:
# pandas.core.series.Series

# %%
df.email #dot notation
# Out:
# 0    corey@gmail.com
# 1    musab@gmail.com
# 2    ahmad@gmail.com
# Name: email, dtype: object

# %%
df[['last', 'email']]
# Out:
#       last            email
# 0   Schexx  corey@gmail.com
# 1  pirzada  musab@gmail.com
# 2     khan  ahmad@gmail.com

# %%
df['last', 'email']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('last', 'email')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.iloc[0] #for accessing rows
# Out:
# first              Corey
# last              Schexx
# email    corey@gmail.com
# Name: 0, dtype: object

# %%
df.iloc[[0,1]] #for accessing multiple rows
# Out:
#    first     last            email
# 0  Corey   Schexx  corey@gmail.com
# 1  musab  pirzada  musab@gmail.com

# %%
df.iloc[[0,2], 2] #first is row and second is column
# Out:
# 0    corey@gmail.com
# 2    ahmad@gmail.com
# Name: email, dtype: object

# %%
df.loc[0]
# Out:
# first              Corey
# last              Schexx
# email    corey@gmail.com
# Name: 0, dtype: object

# %%
df.loc[[0,1],'email']
# Out:
# 0    corey@gmail.com
# 1    musab@gmail.com
# Name: email, dtype: object

# %%
df.loc[[0,1],['email','last']]
# Out:
#              email     last
# 0  corey@gmail.com   Schexx
# 1  musab@gmail.com  pirzada

# %%
ds = pd.read_csv('survey_results_public.csv')
ds
# Out:
#      ResponseId                                         MainBranch  \
# 0             1                                      None of these
# 1             2                     I am a developer by profession
# 2             3  I am not primarily a developer, but I write co...
# 3             4                     I am a developer by profession
# 4             5                     I am a developer by profession
# ..          ...                                                ...
# 722         723                     I am a developer by profession
# 723         724                     I am a developer by profession
# 724         725                     I am a developer by profession
# 725         726                              I am learning to code
# 726         727                     I am a developer by profession
#
#                                             Employment  \
# 0                                                  NaN
# ...

# %%
ds.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
ds['Employment']
# Out:
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
#                              ...
# 722                                  Employed, full-time
# 723                                  Employed, full-time
# 724                                  Employed, full-time
# 725                                   Student, full-time
# 726    Employed, full-time;Student, full-time;Student...
# Name: Employment, Length: 727, dtype: object

# %%
ds['Employment'].value_counts()
# Out:
# Employed, full-time                                                                                                                   490
# Student, full-time                                                                                                                     55
# Independent contractor, freelancer, or self-employed                                                                                   36
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                               26
# Student, full-time;Employed, part-time                                                                                                 21
# Employed, full-time;Student, part-time                                                                                                 14
# Not employed, but looking for work                                                                                                     11
# ...

# %%
ds.loc[0]
# Out:
# ResponseId                         1
# MainBranch             None of these
# Employment                       NaN
# RemoteWork                       NaN
# CodingActivities                 NaN
#                            ...
# TrueFalse_2                      NaN
# TrueFalse_3                      NaN
# SurveyLength                     NaN
# SurveyEase                       NaN
# ConvertedCompYearly              NaN
# Name: 0, Length: 79, dtype: object

# %%
ds.loc[0:3, 'Employment':'EdLevel']
# Out:
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# 3              I don’t code outside of work
#
#                                            EdLevel
# 0                                              NaN
# 1                                              NaN
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
